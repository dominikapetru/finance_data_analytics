# %% [markdown]
# # M&A operations

# %%
#stocks
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

#dataset
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
data1 = yf.download('T','2015-06-02','2015-07-02')
data2 = yf.download('VZ','2015-06-02','2015-07-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data1.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-06-01  34.529999  34.599998  34.240002  34.349998  22.969063  28235700
# 2015-06-02  34.369999  34.529999  34.279999  34.360001  22.975752  19508800
# 2015-06-03  34.450001  35.169998  34.360001  35.029999  23.423763  39115900
# 2015-06-04  34.919998  35.480000  34.779999  35.270000  23.584251  56219000
# 2015-06-05  35.160000  35.169998  34.500000  34.570000  23.116167  36713200

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))

sns.lineplot(x=data1.index,y=data1['Adj Close'], color='#3274A1',label='AT&T',ax=axes[0])
axes[0].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[0].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[0].tick_params(axis='x', rotation=90)
axes[0].set_xlabel("")
axes[0].set_ylabel("Price")

sns.lineplot(x=data2.index,y=data2['Adj Close'], color='#A6266C',label='Verizon',ax=axes[1])
axes[1].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[1].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[1].tick_params(axis='x', rotation=90)
axes[1].set_xlabel("")
axes[1].set_ylabel("Price")

plt.suptitle("Stock market price June 2015",fontsize=20)
plt.savefig('1.png',bbox_inches='tight')
plt.show()

# %%
#T AT&T
#VZ Verizon
data1 = yf.download('T','2015-07-02','2015-08-02')
data2 = yf.download('VZ','2015-07-02','2015-08-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))

sns.lineplot(x=data1.index,y=data1['Adj Close'],color='#3274A1',label='AT&T',ax=axes[0])
axes[0].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[0].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[0].tick_params(axis='x', rotation=90)
axes[0].set_xlabel("")
axes[0].set_ylabel("Price")

sns.lineplot(x=data2.index,y=data2['Adj Close'],color='#A6266C',label='Verizon',ax=axes[1])
axes[1].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[1].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[1].tick_params(axis='x', rotation=90)
axes[1].set_xlabel("")
axes[1].set_ylabel("Price")

plt.suptitle("Stock market price July 2015",fontsize=20)
plt.savefig('2.png',bbox_inches='tight')
plt.show()

# %%
#T AT&T
#VZ Verizon
data1 = yf.download('T','2017-10-02','2017-12-02')
data2 = yf.download('VZ','2017-10-02','2017-12-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))

sns.lineplot(x=data1.index,y=data1['Adj Close'],color='#3274A1',label='AT&T',ax=axes[0])
axes[0].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[0].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[0].tick_params(axis='x', rotation=90)
axes[0].set_xlabel("")
axes[0].set_ylabel("Price")

sns.lineplot(x=data2.index,y=data2['Adj Close'],color='#A6266C',label='Verizon',ax=axes[1])
axes[1].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[1].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[1].tick_params(axis='x', rotation=90)
axes[1].set_xlabel("")
axes[1].set_ylabel("Price")

plt.suptitle("Stock market price October - November 2017",fontsize=20)
plt.savefig('3.png',bbox_inches='tight')
plt.show()

# %%
#T AT&T
#VZ Verizon
data1 = yf.download('T','2018-06-02','2018-07-02')
data2 = yf.download('VZ','2018-06-02','2018-07-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))

sns.lineplot(x=data1.index,y=data1['Adj Close'],color='#3274A1',label='AT&T',ax=axes[0])
axes[0].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[0].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[0].tick_params(axis='x', rotation=90)
axes[0].set_xlabel("")
axes[0].set_ylabel("Price")

sns.lineplot(x=data2.index,y=data2['Adj Close'],color='#A6266C',label='Verizon',ax=axes[1])
axes[1].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[1].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[1].tick_params(axis='x', rotation=90)
axes[1].set_xlabel("")
axes[1].set_ylabel("Price")

plt.suptitle("Stock market price June 2018",fontsize=20)
plt.savefig('4.png',bbox_inches='tight')
plt.show()

# %%
#T AT&T
#VZ Verizon
data1 = yf.download('T','2019-08-02','2019-09-02')
data2 = yf.download('VZ','2019-08-02','2019-09-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))

sns.lineplot(x=data1.index,y=data1['Adj Close'],color='#3274A1',label='AT&T',ax=axes[0])
axes[0].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[0].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[0].tick_params(axis='x', rotation=90)
axes[0].set_xlabel("")
axes[0].set_ylabel("Price")

sns.lineplot(x=data2.index,y=data2['Adj Close'],color='#A6266C',label='Verizon',ax=axes[1])
axes[1].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[1].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[1].tick_params(axis='x', rotation=90)
axes[1].set_xlabel("")
axes[1].set_ylabel("Price")

plt.suptitle("Stock market price August 2019",fontsize=20)
plt.savefig('5.png',bbox_inches='tight')
plt.show()

# %%
#T AT&T
#VZ Verizon
data1 = yf.download('T','2021-02-02','2021-04-02')
data2 = yf.download('VZ','2021-02-02','2021-04-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))

sns.lineplot(x=data1.index,y=data1['Adj Close'],color='#3274A1',label='AT&T',ax=axes[0])
axes[0].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[0].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[0].tick_params(axis='x', rotation=90)
axes[0].set_xlabel("")
axes[0].set_ylabel("Price")

sns.lineplot(x=data2.index,y=data2['Adj Close'],color='#A6266C',label='Verizon',ax=axes[1])
axes[1].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[1].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[1].tick_params(axis='x', rotation=90)
axes[1].set_xlabel("")
axes[1].set_ylabel("Price")

plt.suptitle("Stock market price February - March 2021",fontsize=20)
plt.savefig('6.png',bbox_inches='tight')
plt.show()

# %%
#T AT&T
#VZ Verizon
data1 = yf.download('T','2021-05-02','2021-06-02')
data2 = yf.download('VZ','2021-05-02','2021-06-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))

sns.lineplot(x=data1.index,y=data1['Adj Close'],color='#3274A1',label='AT&T',ax=axes[0])
axes[0].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[0].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[0].tick_params(axis='x', rotation=90)
axes[0].set_xlabel("")
axes[0].set_ylabel("Price")

sns.lineplot(x=data2.index,y=data2['Adj Close'],color='#A6266C',label='Verizon',ax=axes[1])
axes[1].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[1].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[1].tick_params(axis='x', rotation=90)
axes[1].set_xlabel("")
axes[1].set_ylabel("Price")

plt.suptitle("Stock market price May 2021",fontsize=20)
plt.savefig('7.png',bbox_inches='tight')
plt.show()

# %%
#T AT&T
#VZ Verizon
data1 = yf.download('T','2021-08-02','2021-09-02')
data2 = yf.download('VZ','2021-08-02','2021-09-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))

sns.lineplot(x=data1.index,y=data1['Adj Close'],color='#3274A1',label='AT&T',ax=axes[0])
axes[0].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[0].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[0].tick_params(axis='x', rotation=90)
axes[0].set_xlabel("")
axes[0].set_ylabel("Price")

sns.lineplot(x=data2.index,y=data2['Adj Close'],color='#A6266C',label='Verizon',ax=axes[1])
axes[1].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[1].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[1].tick_params(axis='x', rotation=90)
axes[1].set_xlabel("")
axes[1].set_ylabel("Price")

plt.suptitle("Stock market price August 2021",fontsize=20)
plt.savefig('8.png',bbox_inches='tight')
plt.show()

# %%
#T AT&T
#VZ Verizon
data1 = yf.download('T','2021-09-02','2021-10-02')
data2 = yf.download('VZ','2021-09-02','2021-10-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,4))

sns.lineplot(x=data1.index,y=data1['Adj Close'],color='#3274A1',label='AT&T',ax=axes[0])
axes[0].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[0].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[0].tick_params(axis='x', rotation=90)
axes[0].set_xlabel("")
axes[0].set_ylabel("Price")

sns.lineplot(x=data2.index,y=data2['Adj Close'],color='#A6266C',label='Verizon',ax=axes[1])
axes[1].grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
axes[1].xaxis.set_major_locator(plt.MaxNLocator(25))
axes[1].tick_params(axis='x', rotation=90)
axes[1].set_xlabel("")
axes[1].set_ylabel("Price")

plt.suptitle("Stock market price September 2021",fontsize=20)
plt.savefig('9.png',bbox_inches='tight')
plt.show()

# %%
#T AT&T
#VZ Verizon
data1 = yf.download('T','2015-01-19','2022-01-19')
data2 = yf.download('VZ','2015-01-19','2022-01-19')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize =(15, 4))

sns.lineplot(x=data1.index,y=data1['Adj Close'],color='#3274A1',label='AT&T')
sns.lineplot(x=data2.index,y=data2['Adj Close'],color='#A6266C',label='Verizon')
plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("Price")

plt.suptitle("Stock market price 2015 - 2021",fontsize=20)
plt.savefig('10.png',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize =(15, 4))

sns.lineplot(x=data1.index,y=data1['Volume'],color='#3274A1',label='AT&T')
sns.lineplot(x=data2.index,y=data2['Volume'],color='#A6266C',label='Verizon')
plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("Price")

plt.suptitle("Stock market volume 2015 - 2021",fontsize=20)
plt.savefig('10b.png',bbox_inches='tight')
plt.show()

# %%
data1 = pd.read_csv('att.csv')
data1.head(3)
# Out:
#     Period   EPS            SE          Debt  Revenue_Communications  \
# 0  01-2016  0.61  124405000000  122104000000             25937000000
# 1  02-2016  0.55  124371000000  117308000000             25765000000
# 2  03-2016  0.54  124603000000  117239000000             26034000000
#
#    Revenue_Entertainment  Revenue_International
# 0            12658000000             1667000000
# 1            12711000000             1828000000
# 2            12720000000             1879000000

# %%
data1['EPS'] = data1['EPS'].astype(float)
data1['SE'] = data1['SE'].astype(float)
data1['Debt'] = data1['Debt'].astype(float)
data1['Revenue_Communications'] = data1['Revenue_Communications'].astype(float)
data1['Revenue_Entertainment'] = data1['Revenue_Entertainment'].astype(float)
data1['Revenue_International'] = data1['Revenue_International'].astype(float)

# %%
plt.figure(figsize =(15, 4))

sns.lineplot(x=data1['Period'],y=data1['Revenue_Communications'],color='#80bfff',label='Revenue_Communications')
sns.lineplot(x=data1['Period'],y=data1['Revenue_Entertainment'],color='#D1742F',label='Revenue_Warner Media')
sns.lineplot(x=data1['Period'],y=data1['Revenue_International'],color='#2B9553',label='Revenue_Latin America')
plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("US Dollars")

plt.suptitle("AT&T",fontsize=20)
plt.savefig('11.png',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize =(15, 4))

sns.lineplot(x=data1['Period'],y=data1['SE'],color='#8989CC',label='Total assets')
sns.lineplot(x=data1['Period'],y=data1['Debt'],color='#ff7733',label='Long term debt')
plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("US Dollars")

plt.suptitle("AT&T",fontsize=20)
plt.savefig('12.png',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize =(15, 4))

sns.lineplot(x=data1['Period'],y=data1['EPS'],color='#3274A1',label='Earnings per share')
plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("US Dollars")

plt.suptitle("AT&T",fontsize=20)
plt.savefig('13.png',bbox_inches='tight')
plt.show()

# %%
data2 = pd.read_csv('verizon.csv')
data2.head()
# Out:
#     Period   EPS            SE          Debt  Revenue_Consumer  \
# 0  01-2016  1.06  244587000000  103615000000       22004000000
# 1  02-2016  1.05  240753000000  109465000000       22613000000
# 2  03-2016  0.99  242073000000  105060000000       23005000000
# 3  04-2016  0.12  244180000000  107429000000       21564000000
# 4  01-2017  0.85  246731000000  112839000000       20878000000
#
#    Revenue_Bussiness  Revenue_Corporate
# 0         9290000000         1232000000
# 1         9423000000          188000000
# 2         9355000000          798000000
# 3         3277000000         4725000000
# 4         7682000000         1654000000

# %%
data2['EPS'] = data2['EPS'].astype(float)
data2['SE'] = data2['SE'].astype(float)
data2['Debt'] = data2['Debt'].astype(float)
data2['Revenue_Communications'] = data2['Revenue_Consumer'].astype(float)
data2['Revenue_Entertainment'] = data2['Revenue_Bussiness'].astype(float)
data2['Revenue_International'] = data2['Revenue_Corporate'].astype(float)

# %%
plt.figure(figsize =(15, 4))

sns.lineplot(x=data2['Period'],y=data2['Revenue_Consumer'],color='#80bfff',label='Revenue_Consumer')
sns.lineplot(x=data2['Period'],y=data2['Revenue_Bussiness'],color='#D1742F',label='Revenue_Bussiness')
sns.lineplot(x=data2['Period'],y=data2['Revenue_Corporate'],color='#2B9553',label='Revenue_Corporate')
plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("US Dollars")

plt.suptitle("Verizon",fontsize=20)
plt.savefig('14.png',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize =(15, 4))

sns.lineplot(x=data2['Period'],y=data2['SE'],color='#8989CC',label='Total assets')
sns.lineplot(x=data2['Period'],y=data2['Debt'],color='#ff7733',label='Long term debt')
plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("US Dollars")

plt.suptitle("Verizon",fontsize=20)
plt.savefig('15.png',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize =(15, 4))

sns.lineplot(x=data2['Period'],y=data2['EPS'],color='#A6266C',label='Earnings per share')
plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("US Dollars")

plt.suptitle("Verizon",fontsize=20)
plt.savefig('16.png',bbox_inches='tight')
plt.show()

# %%
#T AT&T
#VZ Verizon
data1 = yf.download('T','2015-01-02','2022-01-01')
data2 = yf.download('VZ','2015-01-02','2022-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize =(15, 4))

sns.lineplot(x=data1.index,y=data1['Adj Close'],color='#3274A1',label='AT&T')
plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("US Dollars")

plt.suptitle("Stock price AT&T",fontsize=20)
plt.savefig('17.png',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize =(15, 4))

sns.lineplot(x=data1.index,y=data1['Volume'],color='#3274A1',label='AT&T')
plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("US Dollars")

plt.title("Volume AT&T",fontsize=20)
plt.savefig('18.png',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize =(15, 4))

sns.lineplot(x=data1.index,y=data1['Adj Close'],color='#3274A1',label='Adj Close')
sns.lineplot(x=data1.index,y=data1['Adj Close'].rolling(10).mean(),color='#ff6666',label='MA 10days')
sns.lineplot(x=data1.index,y=data1['Adj Close'].rolling(20).mean(),color='#ff9933',label='MA 20days')
sns.lineplot(x=data1.index,y=data1['Adj Close'].rolling(50).mean(),color='#77b300',label='MA 20days')

plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("US Dollars")

plt.title("Moving Average AT&T",fontsize=20)
plt.savefig('19.png',bbox_inches='tight')
plt.show()

# %%
#daily return
plt.figure(figsize =(15, 4))

sns.histplot(data1['Adj Close'].pct_change(),color='#3274A1',bins=100, kde=True)

plt.grid(axis="x", color="black", alpha=.3, linewidth=2, linestyle=":")
plt.tick_params(axis='x', rotation=90)
plt.xlabel("")
plt.ylabel("Daily return")

plt.title("Daily return AT&T",fontsize=20)
plt.savefig('20.png',bbox_inches='tight')
plt.show()

# %%
df1 = data1.copy()
df2 = data2.copy()
df1['AT&T'] = df1['Adj Close'].pct_change()
df2['Verizon'] = df2['Adj Close'].pct_change()

# %%
#correlation between daily returns of AT&T and Verizon
a = sns.jointplot(df1['AT&T'], df2['Verizon'], kind='reg',color='#3274A1')
a.set_axis_labels('AT&T', 'Verizon', fontsize=15)

plt.savefig('21.png',bbox_inches='tight')
plt.show(a)

# %%
df_daily_return = pd.DataFrame(df1['AT&T'])
df_daily_return['Verizon'] = df2['Verizon']

df_daily_return['AT&T_Adj_Close'] = df1['Adj Close']
df_daily_return['Verizon_Adj_Close'] = df2['Adj Close']
df_daily_return.head()
# Out:
#                 AT&T   Verizon  AT&T_Adj_Close  Verizon_Adj_Close
# Date
# 2015-01-02       NaN       NaN       22.014772          33.892361
# 2015-01-05 -0.009448 -0.008305       21.806786          33.610897
# 2015-01-06  0.001490  0.010092       21.839283          33.950104
# 2015-01-07  0.001207 -0.006453       21.865650          33.731014
# 2015-01-08  0.009949  0.021433       22.083191          34.453976

# %%
#correlation between daily returns of AT&T and Verizon
fig,ax = plt.subplots(figsize=(15,4))
corr = df_daily_return.corr()
sns.set_theme(style="white")

matrix = np.triu(corr)
sns.heatmap(corr, annot=True, mask=matrix, cmap="rocket_r")
plt.title("Correlation AT&T and Verizon",fontsize=20)
plt.savefig('22.png',bbox_inches='tight')
plt.show()

# %%
df_daily_return = df_daily_return.drop(['AT&T_Adj_Close', 'Verizon_Adj_Close'], axis=1)
rets = df_daily_return.dropna()

# %%
area = np.pi * 20

plt.figure(figsize=(6, 4))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')
plt.tick_params(axis='x', rotation=90)

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='black', connectionstyle='arc3,rad=-0.3'))
plt.savefig('23.png',bbox_inches='tight')

# %%
data1['Year'] = pd.DatetimeIndex(data1.index).year
data1.head(3)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2015-01-02  33.590000  33.970001  33.590000  33.869999  22.014780  20564000
# 2015-01-05  33.869999  33.919998  33.520000  33.549999  21.806780  30429100
# 2015-01-06  33.770000  33.810001  33.349998  33.599998  21.839283  29595800
#
#             Year
# Date
# 2015-01-02  2015
# 2015-01-05  2015
# 2015-01-06  2015

# %%
#category
conditions = [(data1['Year'] == 2015),
              (data1['Year'] == 2016),
              (data1['Year'] == 2017),
              (data1['Year'] == 2018),
              (data1['Year'] == 2019),
              (data1['Year'] == 2020),
              (data1['Year'] == 2021)]

values = [2.37, 2.10, 4.76, 2.85, 1.89, -0.75, 2.76]
data1['EPS'] = np.select(conditions, values)

# %%
data1.drop(columns=['Year'], inplace=True)

# %%
data1.head(3)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2015-01-02  33.590000  33.970001  33.590000  33.869999  22.014780  20564000
# 2015-01-05  33.869999  33.919998  33.520000  33.549999  21.806780  30429100
# 2015-01-06  33.770000  33.810001  33.349998  33.599998  21.839283  29595800
#
#              EPS
# Date
# 2015-01-02  2.37
# 2015-01-05  2.37
# 2015-01-06  2.37

# %%
data = data1.filter(['Close'])
dataset = data.values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
len(scaled_data)
# Out:
# 1763

# %%
x_train = []
y_train = []

for i in range(60, 1703):
    x_train.append(scaled_data[i-60:i, 0])
    y_train.append(scaled_data[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
len(y_train)
# Out:
# 1643

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Layer
from tensorflow.keras.models import load_model

# %%
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# Train on 1643 samples
# 1643/1643 [==============================] - 52s 30ms/sample - loss: 0.0037

# %%
# Create the testing data set
training_data_len = len(x_train)
test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse = round(rmse,2)
rmse
# Out:
# 0.46

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae = mean_absolute_error(y_test, predictions)
mae = round(mae,2)
mae
# Out:
# 0.33

# %%
# Plot the data
train = data[1250:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions

# Visualize the data
plt.figure(figsize=(15,4))
plt.title("AT&T Model",fontsize=20)
plt.xlabel('Date')
plt.ylabel('Close Price US Dollars')

plt.plot(train['Close'],color='#3274A1')
plt.plot(valid['Close'],color='#ff6666')
plt.plot(valid['Predictions'],color='#77b300')
plt.legend(['Train', 'Validated', 'Predictions'])

plt.savefig('24.png',bbox_inches='tight')
plt.show()

# %%
valid['Predictions'] = predictions
valid.head()
# Out:
#                 Close  Predictions
# Date
# 2021-07-29  28.290001    27.644651
# 2021-07-30  28.049999    27.643368
# 2021-08-02  28.110001    27.639439
# 2021-08-03  28.190001    27.636705
# 2021-08-04  27.850000    27.638338
